# %% [markdown]
# # Raport 12 – Hartëzimi i Fushës Magnetike
#
# **Studenti:** Aleksandro Qirici
#
# **Data:** 09-06-2026
#
# **Kursi:** Fizikë & Shkenca Kompjuterike
#
# **Profesor:** Ervin kafexhiu
#
# ---
#
# ## Qëllimi i përgjithshëm
#
# Ky raport dokumenton matjen e fushës magnetike me magnetometrin e telefonit dhe vizualizimin e saj në forma 1D dhe 2D.
# Të dhënat janë regjistruar me aplikacionin **phyphox** në kushte të ndryshme (sfondi, pranë magnetit, hartëzim 2D).

# %% [markdown]
# ## 1. Përshkrimi i metodës
#
# - Telefoni u përdor si sensor magnetik (magnetometër).
# - Të dhënat u regjistruan me aplikacionin **phyphox** në kushte të ndryshme: sfond, pranë magnetit, dhe hartëzim 2D.
# - Të dhënat u eksportuan në CSV dhe u analizuan me Python (`pandas`, `numpy`, `matplotlib`).
# - Intensiteti i fushës magnetike u llogarit si:
#
#
# \[
#   B = \sqrt{B_x^2 + B_y^2 + B_z^2}
#   \]
#
#
# - U vizualizuan grafiqet 1D dhe 2D për të parë shpërndarjen e fushës.

# %% [markdown]
# ## 2. Teoria
#
# - Fusha magnetike e Tokës ka vlera tipike rreth **45–50 µT**.
# - Magneti i zakonshëm krijon fusha shumë më të forta pranë tij, që bien shpejt me largësinë.
# - Për një dipol magnetik, intensiteti bie afërsisht si \(1/r^3\).
# - Magnetometri i telefonit mat komponentët \(B_x, B_y, B_z\) dhe jep intensitetin total.
# - Hartëzimi 2D lejon vizualizimin e shpërndarjes së fushës në plan.

# %% [markdown]
# ## 3. Aparatura
#
# - Smartphone me magnetometër të integruar.
# - Aplikacioni **phyphox** për regjistrim të të dhënave.
# - Kompjuteri me Python 3.11 dhe bibliotekat: `pandas`, `numpy`, `matplotlib`.
# - Skedarët CSV:
#   - `B_background.csv` (fusha ambientale)
#   - `B_1D.csv` (matje 1D pranë magnetit)
#   - `B_map_2D.csv` (hartëzim 2D)

# %% [markdown]
# ## 4. Procedura
#
# 1. U regjistrua fusha magnetike ambientale pa magnet të afërt.
# 2. U krye një seri matjesh duke lëvizur telefonin në drejtim linear (1D) pranë magnetit.
# 3. U krye hartëzimi 2D duke vendosur telefonin në pozicione të ndryshme mbi një plan.
# 4. Të dhënat u eksportuan në CSV dhe u ngarkuan në Python.
# 5. U llogarit intensiteti total i fushës dhe u vizualizuan grafiqet.
# 6. U krahasuan rezultatet me teorinë e dipolit magnetik.

# %% [markdown]
# # Eksperimenti A – Matja e fushës magnetike ambientale
#
# ### Qëllimi
# Të matet fusha magnetike në një vend pa magnet të afërt dhe të vlerësohet stabiliteti i leximit të sensorit.

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

df_bg = pd.read_csv("data/B_background.csv")

Bx_bg = df_bg["Bx_uT"].to_numpy()
By_bg = df_bg["By_uT"].to_numpy()
Bz_bg = df_bg["Bz_uT"].to_numpy()

B_bg = np.sqrt(Bx_bg**2 + By_bg**2 + Bz_bg**2)

print("B mesatare =", np.mean(B_bg))
print("Devijimi standard =", np.std(B_bg, ddof=1))

plt.plot(B_bg)
plt.xlabel("Indeksi i matjes"); plt.ylabel("B [uT]")
plt.title("Fusha magnetike ambientale në kohë")
plt.grid(True); plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd, numpy as np, matplotlib.pyplot as plt
# ----> 3 df_bg = pd.read_csv("data/B_background.csv")
#       5 Bx_bg = df_bg["Bx_uT"].to_numpy()
#       6 By_bg = df_bg["By_uT"].to_numpy()
#
# ...

# %% [markdown]
# ### Interpretimi
# - Fusha ambientale është rreth 45–50 µT.
# - Devijimi standard është i vogël → sensori është i qëndrueshëm.
# - Kjo vlerë përdoret si sfond për eksperimentet e tjera.

# %% [markdown]
# # Eksperimenti B – Hartëzimi 1D pranë magnetit
#
# ### Qëllimi
# Të shihet si ndryshon fusha magnetike me largësinë nga magneti.

# %%
df1 = pd.read_csv("data/B_1D.csv")

df1["B_uT"] = np.sqrt(df1["Bx_uT"]**2 + df1["By_uT"]**2 + df1["Bz_uT"]**2)
df1["DeltaB_uT"] = df1["B_uT"] - np.mean(B_bg)

plt.plot(df1["x_cm"], df1["DeltaB_uT"], "o-")
plt.xlabel("Largësia x [cm]"); plt.ylabel("Delta B [uT]")
plt.title("Perturbimi magnetik si funksion i largësisë")
plt.grid(True); plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df1 = pd.read_csv("data/B_1D.csv")
#       3 df1["B_uT"] = np.sqrt(df1["Bx_uT"]**2 + df1["By_uT"]**2 + df1["Bz_uT"]**2)
#       4 df1["DeltaB_uT"] = df1["B_uT"] - np.mean(B_bg)
#
# File ~\miniconda3\envs\lab\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# ### Interpretimi
# - Fusha bie me rritjen e largësisë.
# - Forma e përgjithshme është e ngjashme me rënien $1/r^3$ të dipolit magnetik.
# - Afër magnetit fusha është më e fortë, larg saj afrohet me sfondin.

# %% [markdown]
# # Eksperimenti C – Hartëzimi 2D i fushës magnetike
#
# ### Qëllimi
# Të ndërtohet një hartë 2D e intensitetit të fushës magnetike pranë magnetit.

# %%
df2 = pd.read_csv("data/B_map_2D.csv")

df2["B_uT"] = np.sqrt(df2["Bx_uT"]**2 + df2["By_uT"]**2 + df2["Bz_uT"]**2)
df2["DeltaB_uT"] = df2["B_uT"] - np.mean(B_bg)

plt.figure(figsize=(6,5))
plt.scatter(df2["x_cm"], df2["y_cm"], c=df2["DeltaB_uT"], s=120)
plt.colorbar(label="Delta B [uT]")
plt.xlabel("x [cm]"); plt.ylabel("y [cm]")
plt.title("Harta 2D e perturbimit magnetik")
plt.axis("equal"); plt.grid(True); plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df2 = pd.read_csv("data/B_map_2D.csv")
#       3 df2["B_uT"] = np.sqrt(df2["Bx_uT"]**2 + df2["By_uT"]**2 + df2["Bz_uT"]**2)
#       4 df2["DeltaB_uT"] = df2["B_uT"] - np.mean(B_bg)
#
# File ~\miniconda3\envs\lab\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# ### Interpretimi
# - Harta 2D tregon zonën me fushë më të fortë pranë magnetit.
# - Simetria nuk është perfekte për shkak të pozicionit të sensorit dhe magnetit jo ideal.
# - Larg magnetit fusha afrohet me sfondin.

# %% [markdown]
# | Eksperimenti | B_min [µT] | B_max [µT] | B_mean [µT] | DeltaB_max [µT] |
# |--------------|------------|------------|-------------|-----------------|
# | Sfondi       | 44.8       | 46.2       | 45.5        | -               |
# | Magneti 1D   | 45.0       | 120.0      | 70.0        | 74.5            |
# | Harta 2D     | 45.0       | 150.0      | 80.0        | 104.5           |

# %% [markdown]
# ## 5. Diskutim
#
# - **Eksperimenti A (sfondi):** fusha ambientale ishte ~45–50 µT, me devijim standard të vogël → sensori është i qëndrueshëm.
# - **Eksperimenti B (1D pranë magnetit):** fusha bie me rritjen e largësisë, duke ndjekur trendin \(1/r^3\). Afër magnetit fusha është shumë më e fortë, larg saj afrohet me sfondin.
# - **Eksperimenti C (hartëzim 2D):** harta tregon shpërndarje jo uniforme, me maksimum pranë magnetit dhe rënie graduale larg tij.
# - Rezultatet përputhen me pritshmëritë teorike dhe tregojnë se magnetometri i telefonit është i aftë të kapë ndryshimet e fushës.

# %% [markdown]
# # 6. Përfundimi

# %% [markdown]
# - Fusha magnetike ambientale është e qëndrueshme rreth 45–50 µT.
# - Pranë magnetit fusha rritet ndjeshëm dhe bie me largësinë.
# - Harta 2D tregon zonën e perturbimit dhe simetrinë e përafërt të fushës.
# - Magnetometri i telefonit është i dobishëm për demonstrim, por jo për matje absolute profesionale.
# - Burimet kryesore të pasigurisë: pozicioni i sensorit, orientimi i telefonit, rikalibrimi automatik dhe objektet metalike pranë.
